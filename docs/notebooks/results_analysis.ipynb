# %% [markdown]
# # Analyze simulation results
#
# After installing the repository for the evaluation of the energy consumption of Italian residential buildings.

# %% [markdown]
# ## Import python libraries
# Here you set the path of the main repository

# %%
import sys
sys.path.insert(0, r"C:\Projects\GRINS-Tool")  # <-- insert your path here
from funcs.io_functions import import_output

# %% [markdown]
# ## Import results
# Import results from a previously saved pickle file.

# %%
res = import_output('output_istat2013_weather2013.pickle')
results = res.all

# %% [markdown]
# ## Visualize results
# Visualize a regional heatmap of the residential buildings' energy consumption by energy carrier.

# %%
res.heatmap(column = 2) # 0: electricity, 1: gas , 2: gpl , 3: biomass
# Out:
# C:\Users\vivijac14771\AppData\Local\anaconda3\envs\grinstenv\Lib\site-packages\executing\executing.py:713: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   right=ast.Str(s=sentinel),
# C:\Users\vivijac14771\AppData\Local\anaconda3\envs\grinstenv\Lib\site-packages\executing\executing.py:713: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   right=ast.Str(s=sentinel),
# C:\Users\vivijac14771\AppData\Local\anaconda3\envs\grinstenv\Lib\ast.py:587: DeprecationWarning: Attribute s is deprecated and will be removed in Python 3.14; use value instead
#   return Constant(*args, **kwargs)
# C:\Users\vivijac14771\AppData\Local\anaconda3\envs\grinstenv\Lib\site-packages\executing\executing.py:713: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   right=ast.Str(s=sentinel),
# ...
